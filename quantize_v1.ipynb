# %%
from vision.ssd.mobilenetv1_ssd import create_mobilenetv1_ssd, create_mobilenetv1_ssd_predictor

# %%
import torch
from glob import glob
import cv2
from vision.ssd.data_preprocessing import PredictionTransform
import numpy as np

# %%
label_path = 'models/voc.txt'
class_names = [name.strip() for name in open(label_path).readlines()]

# %%
net = create_mobilenetv1_ssd(len(class_names), is_test=True, device='cpu', quantized=True)
net.load('models/mobilenet-v1-ssd-mp-0_675.pth')
net.cpu().eval()
# Out:
# /home/fano/Desktop/pytorch-ssd-quantization/vision/ssd/ssd.py:146: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.load_state_dict(torch.load(model, map_location=lambda storage, loc: storage))
# SSD(
#   (base_net): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (2): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (3): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (4): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=128, bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (5): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (6): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=256, bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (7): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (8): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (9): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (10): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (11): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (12): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=512, bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (13): Sequential(
#       (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#   )
#   (extras): ModuleList(
#     (0): Sequential(
#       (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU()
#       (2): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (3): ReLU()
#     )
#     (1): Sequential(
#       (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU()
#       (2): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (3): ReLU()
#     )
#     (2-3): 2 x Sequential(
#       (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU()
#       (2): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (3): ReLU()
#     )
#   )
#   (classification_headers): ModuleList(
#     (0): Conv2d(512, 126, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Conv2d(1024, 126, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): Conv2d(512, 126, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3-5): 3 x Conv2d(256, 126, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (regression_headers): ModuleList(
#     (0): Conv2d(512, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Conv2d(1024, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): Conv2d(512, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3-5): 3 x Conv2d(256, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (quant): QuantStub()
#   (dequant): DeQuantStub()
#   (source_layer_add_ons): ModuleList()
# )

# %%
transform = PredictionTransform(300, np.array([127, 127, 127]), 128.0)

orig_image = cv2.imread("imgs/photo_2024-11-20_15-40-16.jpg")
image = cv2.cvtColor(orig_image, cv2.COLOR_BGR2RGB)

# %%
predictor = create_mobilenetv1_ssd_predictor(net, candidate_size=200, device='cpu')

# %%
boxes, labels, probs = predictor.predict(image, 10, 0.4)
# Out:
# Inference time:  0.10707521438598633

# %%
boxes
# Out:
# tensor([[ 85.8516, 223.7919, 227.4944, 370.2946],
#         [235.7860,   0.6387, 499.8279, 377.8770]])

# %%
predictor.trace(image, "checkpoints/traced_m_v1.pt", onnx=False)
# Out:
# Trace time:  1.5798430442810059

# %%
net
# Out:
# SSD(
#   (base_net): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (2): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (3): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (4): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=128, bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (5): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (6): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=256, bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (7): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (8): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (9): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (10): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (11): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (12): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=512, bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (13): Sequential(
#       (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#   )
#   (extras): ModuleList(
#     (0): Sequential(
#       (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU()
#       (2): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (3): ReLU()
#     )
#     (1): Sequential(
#       (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU()
#       (2): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (3): ReLU()
#     )
#     (2-3): 2 x Sequential(
#       (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU()
#       (2): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (3): ReLU()
#     )
#   )
#   (classification_headers): ModuleList(
#     (0): Conv2d(512, 126, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Conv2d(1024, 126, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): Conv2d(512, 126, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3-5): 3 x Conv2d(256, 126, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (regression_headers): ModuleList(
#     (0): Conv2d(512, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Conv2d(1024, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): Conv2d(512, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3-5): 3 x Conv2d(256, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (quant): QuantStub()
#   (dequant): DeQuantStub()
#   (source_layer_add_ons): ModuleList()
# )

# %%
ffuse_list = [
    ["base_net.0.0", "base_net.0.1", "base_net.0.2"],

    ["base_net.1.0", "base_net.1.1", "base_net.1.2"],
    ["base_net.1.3", "base_net.1.4", "base_net.1.5"],

    ["base_net.2.0", "base_net.2.1", "base_net.2.2"],
    ["base_net.2.3", "base_net.2.4", "base_net.2.5"],

    ["base_net.3.0", "base_net.3.1", "base_net.3.2"],
    ["base_net.3.3", "base_net.3.4", "base_net.3.5"],

    ["base_net.4.0", "base_net.4.1", "base_net.4.2"],
    ["base_net.4.3", "base_net.4.4", "base_net.4.5"],   

    ["base_net.5.0", "base_net.5.1", "base_net.5.2"],
    ["base_net.5.3", "base_net.5.4", "base_net.5.5"], 

    ["base_net.6.0", "base_net.6.1", "base_net.6.2"],
    ["base_net.6.3", "base_net.6.4", "base_net.6.5"],

    ["base_net.7.0", "base_net.7.1", "base_net.7.2"],
    ["base_net.7.3", "base_net.7.4", "base_net.7.5"],

    ["base_net.8.0", "base_net.8.1", "base_net.8.2"],
    ["base_net.8.3", "base_net.8.4", "base_net.8.5"],

    ["base_net.9.0", "base_net.9.1", "base_net.9.2"],
    ["base_net.9.3", "base_net.9.4", "base_net.9.5"],

    ["base_net.10.0", "base_net.10.1", "base_net.10.2"],
    ["base_net.10.3", "base_net.10.4", "base_net.10.5"],

    ["base_net.11.0", "base_net.11.1", "base_net.11.2"],
    ["base_net.11.3", "base_net.11.4", "base_net.11.5"],

    ["base_net.12.0", "base_net.12.1", "base_net.12.2"],
    ["base_net.12.3", "base_net.12.4", "base_net.12.5"],

    ["base_net.13.0", "base_net.13.1", "base_net.13.2"],
    ["base_net.13.3", "base_net.13.4", "base_net.13.5"],

    ['extras.0.0', 'extras.0.1'],
    ['extras.0.2', 'extras.0.3'],

    ['extras.1.0', 'extras.1.1'],
    ['extras.1.2', 'extras.1.3'],

    ['extras.2.0', 'extras.2.1'],
    ['extras.2.2', 'extras.2.3'],

    ['extras.3.0', 'extras.3.1'],
    ['extras.3.2', 'extras.3.3'],
]

torch.quantization.fuse_modules(net, ffuse_list, inplace=True)
# Out:
# SSD(
#   (base_net): Sequential(
#     (0): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (1): Identity()
#       (2): Identity()
#     )
#     (1): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#         (1): ReLU(inplace=True)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (2): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64)
#         (1): ReLU(inplace=True)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (3): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#         (1): ReLU(inplace=True)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (4): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=128)
#         (1): ReLU(inplace=True)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (5): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256)
#         (1): ReLU(inplace=True)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (6): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=256)
#         (1): ReLU(inplace=True)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (7): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (1): ReLU(inplace=True)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (8): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (1): ReLU(inplace=True)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (9): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (1): ReLU(inplace=True)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (10): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (1): ReLU(inplace=True)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (11): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (1): ReLU(inplace=True)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (12): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=512)
#         (1): ReLU(inplace=True)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (13): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024)
#         (1): ReLU(inplace=True)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#   )
#   (extras): ModuleList(
#     (0): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU()
#       )
#       (1): Identity()
#       (2): ConvReLU2d(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): ReLU()
#       )
#       (3): Identity()
#     )
#     (1): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU()
#       )
#       (1): Identity()
#       (2): ConvReLU2d(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): ReLU()
#       )
#       (3): Identity()
#     )
#     (2-3): 2 x Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU()
#       )
#       (1): Identity()
#       (2): ConvReLU2d(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): ReLU()
#       )
#       (3): Identity()
#     )
#   )
#   (classification_headers): ModuleList(
#     (0): Conv2d(512, 126, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Conv2d(1024, 126, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): Conv2d(512, 126, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3-5): 3 x Conv2d(256, 126, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (regression_headers): ModuleList(
#     (0): Conv2d(512, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Conv2d(1024, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): Conv2d(512, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3-5): 3 x Conv2d(256, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (quant): QuantStub()
#   (dequant): DeQuantStub()
#   (source_layer_add_ons): ModuleList()
# )

# %%
predictor.trace(image, "checkpoints/traced_m_f_v1.pt", onnx=False)
# Out:
# Trace time:  1.487236499786377

# %%
net.qconfig = torch.quantization.get_default_qconfig("qnnpack")

# %%
for name, value in net.__dict__.items():
    print(f"{name}: {type(value)}")
# Out:
# training: <class 'bool'>
# _parameters: <class 'collections.OrderedDict'>
# _buffers: <class 'collections.OrderedDict'>
# _non_persistent_buffers_set: <class 'set'>
# _backward_pre_hooks: <class 'collections.OrderedDict'>
# _backward_hooks: <class 'collections.OrderedDict'>
# _is_full_backward_hook: <class 'NoneType'>
# _forward_hooks: <class 'collections.OrderedDict'>
# _forward_hooks_with_kwargs: <class 'collections.OrderedDict'>
# _forward_hooks_always_called: <class 'collections.OrderedDict'>
# _forward_pre_hooks: <class 'collections.OrderedDict'>
# _forward_pre_hooks_with_kwargs: <class 'collections.OrderedDict'>
# _state_dict_hooks: <class 'collections.OrderedDict'>
# _state_dict_pre_hooks: <class 'collections.OrderedDict'>
# _load_state_dict_pre_hooks: <class 'collections.OrderedDict'>
# _load_state_dict_post_hooks: <class 'collections.OrderedDict'>
# _modules: <class 'collections.OrderedDict'>
# num_classes: <class 'int'>
# source_layer_indexes: <class 'list'>
# is_test: <class 'bool'>
# config: <class 'module'>
# quantized: <class 'bool'>
# device: <class 'str'>
# priors: <class 'torch.Tensor'>
# qconfig: <class 'torch.ao.quantization.qconfig.QConfig'>

# %%
model_fp32_prepared = torch.quantization.prepare(net, inplace=True)

# %%
model_fp32_prepared
# Out:
# SSD(
#   (base_net): Sequential(
#     (0): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (1): Identity()
#       (2): Identity()
#     )
#     (1): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (2): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64)
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (3): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (4): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=128)
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (5): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256)
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (6): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=256)
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (7): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (8): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (9): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (10): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (11): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (12): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=512)
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (13): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024)
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#   )
#   (extras): ModuleList(
#     (0): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU()
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (1): Identity()
#       (2): ConvReLU2d(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): ReLU()
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (3): Identity()
#     )
#     (1): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU()
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (1): Identity()
#       (2): ConvReLU2d(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): ReLU()
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (3): Identity()
#     )
#     (2-3): 2 x Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU()
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (1): Identity()
#       (2): ConvReLU2d(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): ReLU()
#         (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#       )
#       (3): Identity()
#     )
#   )
#   (classification_headers): ModuleList(
#     (0): Conv2d(
#       512, 126, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#     )
#     (1): Conv2d(
#       1024, 126, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#     )
#     (2): Conv2d(
#       512, 126, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#     )
#     (3-5): 3 x Conv2d(
#       256, 126, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#     )
#   )
#   (regression_headers): ModuleList(
#     (0): Conv2d(
#       512, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#     )
#     (1): Conv2d(
#       1024, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#     )
#     (2): Conv2d(
#       512, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#     )
#     (3-5): 3 x Conv2d(
#       256, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#     )
#   )
#   (quant): QuantStub(
#     (activation_post_process): HistogramObserver(min_val=inf, max_val=-inf)
#   )
#   (dequant): DeQuantStub()
#   (source_layer_add_ons): ModuleList()
# )

# %%
images = glob("imgs/*")
images
# Out:
# ['imgs/photo_2024-11-20_15-40-16.jpg',
#  'imgs/photo_2024-11-20_15-40-15.jpg',
#  'imgs/photo_2024-11-20_15-40-12.jpg',
#  'imgs/photo_2024-11-20_15-40-09.jpg',
#  'imgs/photo_2024-11-20_15-40-14.jpg']

# %%
for image_c in images:
    image_c = cv2.imread(image_c)
    image_c = cv2.cvtColor(orig_image, cv2.COLOR_BGR2RGB)
    image_c = transform(image_c)
    image_c = image_c.unsqueeze(0).cpu()
    with torch.no_grad():
        out = model_fp32_prepared(image_c)

# %%
model_fp32_prepared
# Out:
# SSD(
#   (base_net): Sequential(
#     (0): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=2.597787857055664)
#       )
#       (1): Identity()
#       (2): Identity()
#     )
#     (1): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=5.082990646362305)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=6.782979965209961)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (2): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64)
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=4.301424026489258)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=2.4748001098632812)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (3): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=3.437883138656616)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=2.1112024784088135)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (4): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=128)
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=1.8178755044937134)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=1.3558733463287354)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (5): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256)
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=1.9698103666305542)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=1.3187246322631836)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (6): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=256)
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=2.2377564907073975)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=1.0756398439407349)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (7): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=2.6100194454193115)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=0.792599081993103)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (8): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=1.9218074083328247)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=0.8363224267959595)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (9): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=2.3092901706695557)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=0.8002362251281738)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (10): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=1.923258900642395)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=0.7812275290489197)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (11): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=1.4273911714553833)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=4.950396537780762)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (12): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=512)
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=1.1538435220718384)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=0.633061945438385)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#     (13): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024)
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=0.6413553357124329)
#       )
#       (1): Identity()
#       (2): Identity()
#       (3): ConvReLU2d(
#         (0): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=2.3961029052734375)
#       )
#       (4): Identity()
#       (5): Identity()
#     )
#   )
#   (extras): ModuleList(
#     (0): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU()
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=3.607414722442627)
#       )
#       (1): Identity()
#       (2): ConvReLU2d(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): ReLU()
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=3.5929768085479736)
#       )
#       (3): Identity()
#     )
#     (1): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU()
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=6.6670756340026855)
#       )
#       (1): Identity()
#       (2): ConvReLU2d(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): ReLU()
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=6.053504467010498)
#       )
#       (3): Identity()
#     )
#     (2): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU()
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=7.235040187835693)
#       )
#       (1): Identity()
#       (2): ConvReLU2d(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): ReLU()
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=5.726747512817383)
#       )
#       (3): Identity()
#     )
#     (3): Sequential(
#       (0): ConvReLU2d(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU()
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=6.310074806213379)
#       )
#       (1): Identity()
#       (2): ConvReLU2d(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): ReLU()
#         (activation_post_process): HistogramObserver(min_val=0.0, max_val=5.736762046813965)
#       )
#       (3): Identity()
#     )
#   )
#   (classification_headers): ModuleList(
#     (0): Conv2d(
#       512, 126, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (activation_post_process): HistogramObserver(min_val=-4.673452854156494, max_val=10.05847454071045)
#     )
#     (1): Conv2d(
#       1024, 126, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (activation_post_process): HistogramObserver(min_val=-3.8991611003875732, max_val=10.737170219421387)
#     )
#     (2): Conv2d(
#       512, 126, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (activation_post_process): HistogramObserver(min_val=-3.7847721576690674, max_val=10.37679386138916)
#     )
#     (3): Conv2d(
#       256, 126, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (activation_post_process): HistogramObserver(min_val=-3.7963290214538574, max_val=10.512616157531738)
#     )
#     (4): Conv2d(
#       256, 126, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (activation_post_process): HistogramObserver(min_val=-3.8519766330718994, max_val=8.823587417602539)
#     )
#     (5): Conv2d(
#       256, 126, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (activation_post_process): HistogramObserver(min_val=-3.3454720973968506, max_val=7.87117862701416)
#     )
#   )
#   (regression_headers): ModuleList(
#     (0): Conv2d(
#       512, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (activation_post_process): HistogramObserver(min_val=-10.477378845214844, max_val=3.4225311279296875)
#     )
#     (1): Conv2d(
#       1024, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (activation_post_process): HistogramObserver(min_val=-2.785285711288452, max_val=3.2558977603912354)
#     )
#     (2): Conv2d(
#       512, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (activation_post_process): HistogramObserver(min_val=-2.957698345184326, max_val=3.1715970039367676)
#     )
#     (3): Conv2d(
#       256, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (activation_post_process): HistogramObserver(min_val=-2.6039230823516846, max_val=3.942673683166504)
#     )
#     (4): Conv2d(
#       256, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (activation_post_process): HistogramObserver(min_val=-2.449516773223877, max_val=2.5930228233337402)
#     )
#     (5): Conv2d(
#       256, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (activation_post_process): HistogramObserver(min_val=-2.4397382736206055, max_val=2.921288013458252)
#     )
#   )
#   (quant): QuantStub(
#     (activation_post_process): HistogramObserver(min_val=-0.9921875, max_val=1.0)
#   )
#   (dequant): DeQuantStub()
#   (source_layer_add_ons): ModuleList()
# )

# %%
model_quantized = torch.quantization.convert(model_fp32_prepared, inplace=True)

# %%
predictor = create_mobilenetv1_ssd_predictor(model_quantized, candidate_size=200, device='cpu')
boxes, labels, probs = predictor.predict(image, 10, 0.3)
# Out:
# Inference time:  0.06466794013977051

# %%
predictor.trace(image, "checkpoints/traced_m_f_q_v1.pt", onnx=False)
# Out:
# Trace time:  2.215386152267456

# %%
boxes
# Out:
# tensor([[ 86.3826, 224.7834, 227.4442, 370.9722],
#         [238.4839,  -2.0321, 497.7625, 377.0321]])
